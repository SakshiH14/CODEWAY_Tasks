# %% [markdown]
# <a href="https://colab.research.google.com/github/SakshiH14/CODEWAY_Tasks/blob/main/Codeway_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class TodoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task):
        self.tasks.append(task)
        print(f"Task '{task}' added successfully.")

    def view_tasks(self):
        if not self.tasks:
            print("No tasks found.")
        else:
            print("Your To-Do List:")
            for index, task in enumerate(self.tasks, start=1):
                print(f"{index}. {task}")

    def update_task(self, index, new_task):
        if 1 <= index <= len(self.tasks):
            self.tasks[index - 1] = new_task
            print(f"Task {index} updated successfully.")
        else:
            print("Invalid task index.")

    def remove_task(self, index):
        if 1 <= index <= len(self.tasks):
            removed_task = self.tasks.pop(index - 1)
            print(f"Task '{removed_task}' removed successfully.")
        else:
            print("Invalid task index.")

def main():
    todo_list = TodoList()

    while True:
        print("\nMenu:")
        print("1. Add Task")
        print("2. View Tasks")
        print("3. Update Task")
        print("4. Remove Task")
        print("5. Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == '1':
            task = input("Enter the task: ")
            todo_list.add_task(task)
        elif choice == '2':
            todo_list.view_tasks()
        elif choice == '3':
            index = int(input("Enter the task index to update: "))
            new_task = input("Enter the new task: ")
            todo_list.update_task(index, new_task)
        elif choice == '4':
            index = int(input("Enter the task index to remove: "))
            todo_list.remove_task(index)
        elif choice == '5':
            print("Exiting the To-Do List application. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 5.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 1
# Enter the task: Study for interview
# Task 'Study for interview' added successfully.
#
# Menu:
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 2
# Your To-Do List:
# 1. Study for interview
#
# Menu:
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 3
# Enter the task index to update: 1
# Enter the new task: Study for 3 hours
# Task 1 updated successfully.
#
# Menu:
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 2
# Your To-Do List:
# 1. Study for 3 hours
#
# Menu:
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 2
# Your To-Do List:
# 1. Study for 3 hours
#
# Menu:
# 1. Add Task
# 2. View Tasks
# 3. Update Task
# 4. Remove Task
# 5. Exit
# Enter your choice (1-5): 4
# ...

# %% [markdown]
# TASK - 1 TO-DO LIST
#
# A To-Do List application is a useful project that helps users manage
# and organize their tasks efficiently. This project aims to create a
# command-line or GUI-based application using Python, allowing users
# to create, update, and track their to-do lists.

# %%
#using tkinter:
import tkinter as tk
from tkinter import messagebox

class TodoListApp:
    def __init__(self, root):
        self.root = root
        self.root.title("To-Do List App")

        self.tasks = []

        self.task_entry = tk.Entry(root, width=40)
        self.task_entry.pack(pady=10)

        add_button = tk.Button(root, text="Add Task", command=self.add_task)
        add_button.pack()

        view_button = tk.Button(root, text="View Tasks", command=self.view_tasks)
        view_button.pack()

        update_button = tk.Button(root, text="Update Task", command=self.update_task)
        update_button.pack()

        remove_button = tk.Button(root, text="Remove Task", command=self.remove_task)
        remove_button.pack()

    def add_task(self):
        task = self.task_entry.get()
        if task:
            self.tasks.append(task)
            messagebox.showinfo("Success", f"Task '{task}' added successfully.")
        else:
            messagebox.showwarning("Warning", "Please enter a task.")

    def view_tasks(self):
        if not self.tasks:
            messagebox.showinfo("Info", "No tasks found.")
        else:
            tasks_str = "\n".join([f"{index + 1}. {task}" for index, task in enumerate(self.tasks)])
            messagebox.showinfo("Your To-Do List", tasks_str)

    def update_task(self):
        index = self.get_task_index()
        if index is not None:
            new_task = self.task_entry.get()
            if new_task:
                self.tasks[index] = new_task
                messagebox.showinfo("Success", f"Task {index + 1} updated successfully.")
            else:
                messagebox.showwarning("Warning", "Please enter a new task.")

    def remove_task(self):
        index = self.get_task_index()
        if index is not None:
            removed_task = self.tasks.pop(index)
            messagebox.showinfo("Success", f"Task '{removed_task}' removed successfully.")

    def get_task_index(self):
        try:
            index = int(messagebox.askinteger("Task Index", "Enter the task index: ")) - 1
            if 0 <= index < len(self.tasks):
                return index
            else:
                messagebox.showwarning("Warning", "Invalid task index.")
                return None
        except ValueError:
            messagebox.showwarning("Warning", "Invalid input. Please enter a number.")
            return None

def main():
    root = tk.Tk()
    app = TodoListApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-10-23f49f7d9092> in <cell line: 75>()
#      74
#      75 if __name__ == "__main__":
# ---> 76     main()
#
# <ipython-input-10-23f49f7d9092> in main()
#      69
#      70 def main():
# ---> 71     root = tk.Tk()
#      72     app = TodoListApp(root)
#      73     root.mainloop()
#
# /usr/lib/python3.10/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2297                 baseName = baseName + ext
#    2298         interactive = False
# -> 2299         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2300         if useTk:
#    2301             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
